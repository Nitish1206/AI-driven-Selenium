# %%
html="""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>KYC Fraud Detection</title>
</head>
  
<body>
    <h1>Automation Testing Demo</h1>
    <link href="{{ url_for('static', filename='style.css') }}" rel="stylesheet">
    
    
    <form action="{{ url_for('feedback') }}" method="GET" enctype=multipart/form-data>


        <label for="name">Name:</label>
        <input type="text" id="name" name="name" required><br>

        <label for="address">Address:</label>
        <input type="text" id="complete-address" name="address" required><br>

        <label for="phone-number">Phone Number:</label>
        <input type="text" id="mobile number" name="phone-number" required><br>

        <label for="dob">Date of Birth:</label>
        <input type="date" id="dob" name="dob" required><br>

        <label for="gender">Gender:</label>
        <select id="gender" name="gender">
            <option value="Male">Male</option>
            <option value="Female">Female</option>
            <option value="Other">Other</option>
        </select><br>

        <label for="father-name">Father's Name:</label>
        <input type="text" id="father-name" name="father-name" required><br>

        <label for="mother-name">Mother's Name:</label>
        <input type="text" id="mother-name" name="mother-name" required><br>


        <input type="submit"  value="Submit" >
    </form>

    

    <script>
        // Function to toggle the visibility of card number fields based on card type
   
    </script>
</body>
</html>"""

# %%
html2="""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>KYC Fraud Detection</title>
</head>
  
<body>
    <h1>Automation Testing Demo</h1>
    <link href="{{ url_for('static', filename='style.css') }}" rel="stylesheet">
    
    
    <form action="{{ url_for('feedback') }}" method="GET" enctype=multipart/form-data>


        <label for="name">Name:</label>
        <input type="text" id="name" name="name" required><br>

        <label for="address">Address:</label>
        <input type="text" id="address" name="address" required><br>

        <label for="phone-number">Phone Number:</label>
        <input type="text" id="phone-number" name="phone-number" required><br>

        <label for="dob">Date of Birth:</label>
        <input type="date" id="dob" name="dob" required><br>

        <label for="gender">Gender:</label>
        <select id="gender" name="gender">
            <option value="Male">Male</option>
            <option value="Female">Female</option>
            <option value="Other">Other</option>
        </select><br>

        <label for="father-name">Father's Name:</label>
        <input type="text" id="father-name" name="father-name" required><br>

        <label for="mother-name">Mother's Name:</label>
        <input type="text" id="mother-name" name="mother-name" required><br>


        <input type="submit"  value="Submit" >
    </form>

    

    <script>
        // Function to toggle the visibility of card number fields based on card type
   
    </script>
</body>
</html>"""

# %%
import nltk

# %%
# nltk.download("all")

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
import math
import re
from collections import Counter

WORD = re.compile(r"\w+")

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
 def extract_element_info(element):
        info = {
            "element": element.name,
            "tag": element.name if element.name != "none" else "none",
            "type": element.get('type', 'none'),
            "id": element.get('id', 'none'),
            "name": element.get('name', 'none'),
            "text": element.text.strip(),
            "value": element.get('value', 'none'),
            "for": element.get('for', 'none')
        }
        return info

# %%
def feature_list(df):
        new_features, new_labels = [], []

        for index, row in df.iterrows():
                feature_values = [str(value) for value in row.values]
                feature_text = ' '.join(feature_values[1:])
                label_text = ''.join(feature_values[0])
                vec=text_to_vector(feature_text)
                new_features.append(vec)
                # new_labels.append(label_text)

        return new_features

# %%
def get_cosine(vec1, vec2):
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])

    sum1 = sum([vec1[x] ** 2 for x in list(vec1.keys())])
    sum2 = sum([vec2[x] ** 2 for x in list(vec2.keys())])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator

# %%
def text_to_vector(text):
    words = WORD.findall(text)
    return Counter(words)

# %%
soup = BeautifulSoup(html, 'html.parser')
all_elements = soup.find_all(['label', 'input', 'select', 'option'])
element_info_list = [extract_element_info(element) for element in all_elements]
df = pd.DataFrame.from_dict(element_info_list)

# %%
df
# Out:
#    element     tag    type                id          name  \
# 0    label   label    none              none          none
# 1    input   input    text              name          name
# 2    label   label    none              none          none
# 3    input   input    text  complete-address       address
# 4    label   label    none              none          none
# 5    input   input    text     mobile number  phone-number
# 6    label   label    none              none          none
# 7    input   input    date               dob           dob
# 8    label   label    none              none          none
# 9   select  select    none            gender        gender
# 10  option  option    none              none          none
# 11  option  option    none              none          none
# 12  option  option    none              none          none
# 13   label   label    none              none          none
# 14   input   input    text       father-name   father-name
# ...

# %%
features_list=feature_list(df)

# %%
soup2 = BeautifulSoup(html2, 'html.parser')
all_elements2 = soup2.find_all(['label', 'input', 'select', 'option'])
element_info_list2 = [extract_element_info(element) for element in all_elements2]
df2 = pd.DataFrame.from_dict(element_info_list2)

# %%
features_list2=feature_list(df2)

# %%
df2
# Out:
#    element     tag    type            id          name                 text  \
# 0    label   label    none          none          none                Name:
# 1    input   input    text          name          name
# 2    label   label    none          none          none             Address:
# 3    input   input    text       address       address
# 4    label   label    none          none          none        Phone Number:
# 5    input   input    text  phone-number  phone-number
# 6    label   label    none          none          none       Date of Birth:
# 7    input   input    date           dob           dob
# 8    label   label    none          none          none              Gender:
# 9   select  select    none        gender        gender  Male\nFemale\nOther
# 10  option  option    none          none          none                 Male
# 11  option  option    none          none          none               Female
# ...

# %%
attributes={"id":"phone-number"}
locator_type_, locator_value_ = next(iter(attributes.items()))

# print(df)

print("*"*15,locator_type_)
print("*"*15,locator_value_)

label_address_rows = df2[df2[locator_type_] == locator_value_]
test_list=label_address_rows.values.tolist()[0]
test_text = ' '.join(test_list)
test_vec=text_to_vector(test_text)
# Out:
# *************** id
# *************** phone-number

# %%
i=0
for f1 in features_list:
    cosine = get_cosine(f1, test_vec)
    print(i,cosine)
    
    i+=1
# Out:
# 0 0.4451319072597257
# 1 0.5368754921931592
# 2 0.4451319072597257
# 3 0.5118906968889915
# 4 0.6351073488299558
# 5 0.9101820546182064
# 6 0.4234048992199705
# 7 0.4601789933084222
# 8 0.4451319072597257
# 9 0.35294117647058826
# 10 0.4234048992199705
# 11 0.4234048992199705
# 12 0.4234048992199705
# 13 0.4136701519960153
# 14 0.4537426064865151
# 15 0.4136701519960153
# 16 0.4537426064865151
# 17 0.560112033611204

# %%
df.iloc[5]["id"]
# Out:
# 'mobile number'
